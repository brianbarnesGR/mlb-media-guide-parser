# %%
import pandas as pd
from bs4 import BeautifulSoup
from nameparser import HumanName
import requests

# %%
team = 'SD'
df = pd.DataFrame()

# %% [markdown]
# # 2018 - 2020

# %%
_source = {
    #2020:
}

# %%
employees = {
    2020: {
        
    }
}

# %% [markdown]
# # 2021 - Present

# %%
_source = {
    2023: 'https://web.archive.org/web/20230326092234/https://www.mlb.com/padres/team/front-office',
    2022: 'https://web.archive.org/web/20220323041148/https://www.mlb.com/padres/team/front-office'
    # 2021: 'https://web.archive.org/web/20210331155729/https://www.mlb.com/padres/team/front-office'
}

# %%
df = pd.DataFrame()

for year in _source.keys():
    res = requests.get(_source[year])
    soup = BeautifulSoup(res.content)

    raw = [y for y in [x.text.strip('\n').split('\n') for x in soup.select('h3, div.p-table__title, tr')] if y[0] != 'Title']
    deps = [x.text for x in soup.select('h3.p-heading__text')]

    department = None
    office = None

    for _ in raw:
        if _[0] in deps:
            department = _[0].title()
            office = None
        elif len(_) == 1:
            office = _[0].title()
        else:
            title = _[0]
            name = _[1]
            
            df = pd.concat([
                df, 
                pd.DataFrame({
                    'Year': year,
                    'Team': team,
                    'NameLast': [HumanName(name).last],
                    'NameFirst': [HumanName(name).first],
                    'Title': [title],
                    'Department': [department],
                    'Source of Information': [_source[year]]
                })])

df
# Out:
#     Year Team   NameLast NameFirst  \
# 0   2023   SD    Seidler     Peter
# 0   2023   SD   Greupner      Erik
# 0   2023   SD    Preller      A.J.
# 0   2023   SD      Perry  Caroline
# 0   2023   SD     Schang  Virginia
# ..   ...  ...        ...       ...
# 0   2022   SD       Lugo   Jessica
# 0   2022   SD       West     Jason
# 0   2022   SD    Sanchez   Crystal
# 0   2022   SD       Dill   Chelsea
# 0   2022   SD  DiMartino   Melissa
#
#                                                 Title  \
# 0                                            Chairman
# 0                             Chief Executive Officer
# 0   President of Baseball Operations & General Man...
# 0                             Chief Operating Officer
# 0                      Executive Assistant to the CEO
# ..                                                ...
# 0             Account Specialist, Membership Services
# 0             Account Specialist, Membership Services
# 0             Account Specialist, Membership Services
# 0                Director, Tourism & Corporate Events
# 0                          Manager, Travel & Tourism
#
#                  Department                              Source of Information
# 0                Executives  https://web.archive.org/web/20230326092234/htt...
# 0                Executives  https://web.archive.org/web/20230326092234/htt...
# 0                Executives  https://web.archive.org/web/20230326092234/htt...
# 0                Executives  https://web.archive.org/web/20230326092234/htt...
# 0   Executive Support Staff  https://web.archive.org/web/20230326092234/htt...
# ..                      ...                                                ...
# 0              Ticket Sales  https://web.archive.org/web/20220323041148/htt...
# 0              Ticket Sales  https://web.archive.org/web/20220323041148/htt...
# 0              Ticket Sales  https://web.archive.org/web/20220323041148/htt...
# 0              Ticket Sales  https://web.archive.org/web/20220323041148/htt...
# 0              Ticket Sales  https://web.archive.org/web/20220323041148/htt...
#
# [610 rows x 7 columns]

# %%
df[['Year', 'Team', 'NameLast', 'NameFirst', 'Title', 'Department', 'Source of Information']] \
    .to_excel(f'../out/{team}-{min(_source.keys())}-to-{max(_source.keys())}.xlsx', index=False)
