# %%
import pandas as pd
from bs4 import BeautifulSoup
from nameparser import HumanName
import requests

# %%
team = 'PIT'
df = pd.DataFrame()

# %% [markdown]
# # 2018 - 2020

# %%
_source = {
    #2020:
}

# %%
employees = {
    2020: {
        
    }
}

# %% [markdown]
# # 2022 - Present

# %%
_source = {
    # 2023: 'https://web.archive.org/web/20230326092133/https://www.mlb.com/pirates/team/front-office',
    # 2022: 'https://web.archive.org/web/20220324054522/https://www.mlb.com/pirates/team/front-office',
    2021: 'https://web.archive.org/web/20210331151440/https://www.mlb.com/pirates/team/front-office',
    2020: 'https://web.archive.org/web/20200621082435/https://www.mlb.com/pirates/team/front-office'
}

# %%
df = pd.DataFrame()

for year in _source.keys():
    res = requests.get(_source[year])
    soup = BeautifulSoup(res.content)

    raw = [y for y in [x.text.strip().split('\n') for x in soup.select('h3, div.p-heading, div.p-table__title, tr')] if y[0] != 'Title' and y[0] != ''][3:]

    if year in [2020, 2021]:
        deps = [x.text.strip() for x in soup.select('div.p-heading')]
    else:
        deps = [x.text.strip() for x in soup.select('h3.p-heading__text')]

    department = 'Executive'
    office = None

    for _ in raw:
        if _[0].strip() in deps:
            department = _[0].title()
            office = None
        elif len(_) == 1:
            office = _[0].title()
        else:
            title = _[0]
            name = _[1]
            
            df = pd.concat([
                df, 
                pd.DataFrame({
                    'Year': year,
                    'Team': team,
                    'NameLast': [HumanName(name).last],
                    'NameFirst': [HumanName(name).first],
                    'Title': [title],
                    'Department': [department],
                    'Source of Information': [_source[year]]
                })])

df
# Out:
#     Year Team    NameLast NameFirst  \
# 0   2021  PIT    Williams    Travis
# 0   2021  PIT       Russo     Nayli
# 0   2021  PIT      Trunzo     Molly
# 0   2021  PIT  Cherington       Ben
# 0   2021  PIT       Stroh     Bryan
# ..   ...  ...         ...       ...
# 0   2020  PIT      Wilder     David
# 0   2020  PIT        Baez     Carly
# 0   2020  PIT       Fogel   Spencer
# 0   2020  PIT    Quintana     Jorge
# 0   2020  PIT     Hassett     Linda
#
#                                           Title           Department  \
# 0                                     President            Executive
# 0                      Vice President, Strategy            Executive
# 0    Senior Executive Assistant, Team President            Executive
# 0                               General Manager  Baseball Operations
# 0   Senior Vice President, Baseball Development  Baseball Operations
# ..                                          ...                  ...
# 0            Clubhouse Assistant, Bradenton, FL   Florida Operations
# 0                      Administrative Assistant   Florida Operations
# 0               Coordinator, Florida Operations   Florida Operations
# 0                  Florida Operations Assistant   Florida Operations
# 0                         Supervisor Front Desk   Florida Operations
#
#                                 Source of Information
# 0   https://web.archive.org/web/20210331151440/htt...
# 0   https://web.archive.org/web/20210331151440/htt...
# 0   https://web.archive.org/web/20210331151440/htt...
# 0   https://web.archive.org/web/20210331151440/htt...
# 0   https://web.archive.org/web/20210331151440/htt...
# ..                                                ...
# 0   https://web.archive.org/web/20200621082435/htt...
# 0   https://web.archive.org/web/20200621082435/htt...
# 0   https://web.archive.org/web/20200621082435/htt...
# 0   https://web.archive.org/web/20200621082435/htt...
# 0   https://web.archive.org/web/20200621082435/htt...
#
# [602 rows x 7 columns]

# %%
df[['Year', 'Team', 'NameLast', 'NameFirst', 'Title', 'Department', 'Source of Information']] \
    .to_excel(f'../out/{team}-{min(_source.keys())}-to-{max(_source.keys())}.xlsx', index=False)
