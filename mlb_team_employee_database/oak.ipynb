# %%
import pandas as pd
from bs4 import BeautifulSoup
from nameparser import HumanName
import requests

# %% [markdown]
# # 2018 - Present

# %%
team = 'OAK'

_source = {
    2023: 'https://web.archive.org/web/20230306062140/https://www.mlb.com/athletics/team/front-office',
    2022: 'https://web.archive.org/web/20220323195743/https://www.mlb.com/athletics/team/front-office',
    2021: 'https://web.archive.org/web/20210318021958/https://www.mlb.com/athletics/team/front-office'
}

# %%
final_df = pd.DataFrame()
front_office_directory = dict()

for year in _source.keys():
    front_office_directory[year] = pd.read_html(_source[year])

# %%
employees = {
    2023: {
        'Executives': front_office_directory[2023][0],
        'Office of the President': front_office_directory[2023][1],
        'Baseball Operations': front_office_directory[2023][2],
        'Communications, Community & Marketing': pd.concat([
            front_office_directory[2023][3],
            front_office_directory[2023][4],
            front_office_directory[2023][5],
            front_office_directory[2023][6],
            front_office_directory[2023][7],
            front_office_directory[2023][8],
            front_office_directory[2023][9]
        ]),
        'Corporate Partnerships': pd.concat([
            front_office_directory[2023][10],
            front_office_directory[2023][11]
        ]),
        'Ticketing & Business Analytics': pd.concat([
            front_office_directory[2023][12],
            front_office_directory[2023][13],
            front_office_directory[2023][14],
            front_office_directory[2023][15],
            front_office_directory[2023][16],
            front_office_directory[2023][17]
        ]),
        'Stadium Operations': pd.concat([
            front_office_directory[2023][18],
            front_office_directory[2023][19]
        ]),
        'Real Estate': front_office_directory[2023][20],
        'Administration': front_office_directory[2023][21],
        'Legal, People Operations & Technology': pd.concat([
            front_office_directory[2023][22],
            front_office_directory[2023][23],
            front_office_directory[2023][24],
            front_office_directory[2023][25]
        ]),
        'Finance & Accounting': pd.concat([
            front_office_directory[2023][26],
            front_office_directory[2023][27]
        ])
    },
    2022: {
        'Executives': front_office_directory[2022][0],
        'Office of the President': front_office_directory[2022][1],
        'Baseball Operations': front_office_directory[2022][2],
        'Communications, Community & Marketing': pd.concat([
            front_office_directory[2022][3],
            front_office_directory[2022][4],
            front_office_directory[2022][5],
            front_office_directory[2022][6],
            front_office_directory[2022][7],
            front_office_directory[2022][8]
        ]),
        'Corporate Partnerships': pd.concat([
            front_office_directory[2022][9],
            front_office_directory[2022][10]
        ]),
        'Ticketing & Business Analytics': pd.concat([
            front_office_directory[2022][11],
            front_office_directory[2022][12],
            front_office_directory[2022][13],
            front_office_directory[2022][14],
            front_office_directory[2022][15],
            front_office_directory[2022][16]
        ]),
        'Stadium Operations': pd.concat([
            front_office_directory[2022][17],
            front_office_directory[2022][18]
        ]),
        'Real Estate': front_office_directory[2022][19],
        'Administration': front_office_directory[2022][20],
        'Legal, People Operations & Technology': pd.concat([
            front_office_directory[2022][21],
            front_office_directory[2022][22],
            front_office_directory[2022][23],
            front_office_directory[2022][24]
        ]),
        'Finance & Accounting': pd.concat([
            front_office_directory[2022][25],
            front_office_directory[2022][26]
        ])
    },
    2021: {
        'Executives': front_office_directory[2021][0],
        'Office of the President': front_office_directory[2021][1],
        'Baseball Operations': front_office_directory[2021][2],
        'Communications, Community & Marketing': pd.concat([
            front_office_directory[2021][3],
            front_office_directory[2021][4],
            front_office_directory[2021][5],
            front_office_directory[2021][6],
            front_office_directory[2021][7],
            front_office_directory[2021][8]
        ]),
        'Corporate Partnerships': pd.concat([
            front_office_directory[2021][9],
            front_office_directory[2021][10]
        ]),
        'Ticketing & Business Analytics': pd.concat([
            front_office_directory[2021][11],
            front_office_directory[2021][12],
            front_office_directory[2021][13],
            front_office_directory[2021][14],
            front_office_directory[2021][15],
            front_office_directory[2021][16]
        ]),
        'Stadium Operations': pd.concat([
            front_office_directory[2021][17],
            front_office_directory[2021][18]
        ]),
        'Real Estate': front_office_directory[2021][19],
        'Administration': front_office_directory[2021][20],
        'Legal, People Operations & Technology': pd.concat([
            front_office_directory[2021][21],
            front_office_directory[2021][22],
            front_office_directory[2021][23],
            front_office_directory[2021][24]
        ]),
        'Finance & Accounting': pd.concat([
            front_office_directory[2021][25],
            front_office_directory[2021][26]
        ])
    }
}

for year in range(min(_source.keys()), max(_source.keys()) + 1):
    for k in employees[year]:
        employees[year][k]['Year'] = year
        employees[year][k]['Department'] = k
        employees[year][k]['Source of Information'] = _source[year]
        final_df = pd.concat((final_df, employees[year][k]))

final_df.dropna(subset=['Name', 'Title'], inplace=True)

# %%
employees = {
    2023: {
        'Executives': front_office_directory[2023][0],
        'Office of the President': front_office_directory[2023][1],
        'Baseball Operations': front_office_directory[2023][2],
        'Communications, Community & Marketing': pd.concat([
            front_office_directory[2023][3],
            front_office_directory[2023][4],
            front_office_directory[2023][5],
            front_office_directory[2023][6],
            front_office_directory[2023][7],
            front_office_directory[2023][8],
            front_office_directory[2023][9]
        ]),
        'Corporate Partnerships': pd.concat([
            front_office_directory[2023][10],
            front_office_directory[2023][11]
        ]),
        'Ticketing & Business Analytics': pd.concat([
            front_office_directory[2023][12],
            front_office_directory[2023][13],
            front_office_directory[2023][14],
            front_office_directory[2023][15],
            front_office_directory[2023][16],
            front_office_directory[2023][17]
        ]),
        'Stadium Operations': pd.concat([
            front_office_directory[2023][18],
            front_office_directory[2023][19]
        ]),
        'Real Estate': front_office_directory[2023][20],
        'Administration': front_office_directory[2023][21],
        'Legal, People Operations & Technology': pd.concat([
            front_office_directory[2023][22],
            front_office_directory[2023][23],
            front_office_directory[2023][24],
            front_office_directory[2023][25]
        ]),
        'Finance & Accounting': pd.concat([
            front_office_directory[2023][26],
            front_office_directory[2023][27]
        ])
    },
    2022: {
        'Executives': front_office_directory[2022][0],
        'Office of the President': front_office_directory[2022][1],
        'Baseball Operations': front_office_directory[2022][2],
        'Communications, Community & Marketing': pd.concat([
            front_office_directory[2022][3],
            front_office_directory[2022][4],
            front_office_directory[2022][5],
            front_office_directory[2022][6],
            front_office_directory[2022][7],
            front_office_directory[2022][8]
        ]),
        'Corporate Partnerships': pd.concat([
            front_office_directory[2022][9],
            front_office_directory[2022][10]
        ]),
        'Ticketing & Business Analytics': pd.concat([
            front_office_directory[2022][11],
            front_office_directory[2022][12],
            front_office_directory[2022][13],
            front_office_directory[2022][14],
            front_office_directory[2022][15],
            front_office_directory[2022][16]
        ]),
        'Stadium Operations': pd.concat([
            front_office_directory[2022][17],
            front_office_directory[2022][18]
        ]),
        'Real Estate': front_office_directory[2022][19],
        'Administration': front_office_directory[2022][20],
        'Legal, People Operations & Technology': pd.concat([
            front_office_directory[2022][21],
            front_office_directory[2022][22],
            front_office_directory[2022][23],
            front_office_directory[2022][24]
        ]),
        'Finance & Accounting': pd.concat([
            front_office_directory[2022][25],
            front_office_directory[2022][26]
        ])
    },
    2021: {
        'Executives': front_office_directory[2021][0],
        'Office of the President': front_office_directory[2021][1],
        'Baseball Operations': front_office_directory[2021][2],
        'Communications, Community & Marketing': pd.concat([
            front_office_directory[2021][3],
            front_office_directory[2021][4],
            front_office_directory[2021][5],
            front_office_directory[2021][6],
            front_office_directory[2021][7],
            front_office_directory[2021][8]
        ]),
        'Corporate Partnerships': pd.concat([
            front_office_directory[2021][9],
            front_office_directory[2021][10]
        ]),
        'Ticketing & Business Analytics': pd.concat([
            front_office_directory[2021][11],
            front_office_directory[2021][12],
            front_office_directory[2021][13],
            front_office_directory[2021][14],
            front_office_directory[2021][15],
            front_office_directory[2021][16]
        ]),
        'Stadium Operations': pd.concat([
            front_office_directory[2021][17],
            front_office_directory[2021][18]
        ]),
        'Real Estate': front_office_directory[2021][19],
        'Administration': front_office_directory[2021][20],
        'Legal, People Operations & Technology': pd.concat([
            front_office_directory[2021][21],
            front_office_directory[2021][22],
            front_office_directory[2021][23],
            front_office_directory[2021][24]
        ]),
        'Finance & Accounting': pd.concat([
            front_office_directory[2021][25],
            front_office_directory[2021][26]
        ])
    }
}

for year in range(min(_source.keys()), max(_source.keys()) + 1):
    for k in employees[year]:
        employees[year][k]['Year'] = year
        employees[year][k]['Department'] = k
        employees[year][k]['Source of Information'] = _source[year]
        final_df = pd.concat((final_df, employees[year][k]))

final_df.dropna(subset=['Name', 'Title'], inplace=True)

# %%
final_df['Team'] = team
final_df['NameLast'] = final_df.Name.apply(lambda x: HumanName(x).last)
final_df['NameFirst'] = final_df.Name.apply(lambda x: HumanName(x).first)

final_df[['Year', 'Team', 'NameLast', 'NameFirst', 'Title', 'Department', 'Source of Information']]
# Out:
#     Year Team  NameLast NameFirst  \
# 0   2021  OAK    Fisher      John
# 1   2021  OAK     Kaval     David
# 2   2021  OAK     Beane     Billy
# 3   2021  OAK     Wolff       Lew
# 4   2021  OAK    Gurtin      Bill
# ..   ...  ...       ...       ...
# 3   2023  OAK    Magaña   Charlie
# 4   2023  OAK    Cramer      Dave
# 5   2023  OAK  Espinoza   Michael
# 6   2023  OAK   Erskine      Alex
# 0   2023  OAK    Causey   Matthew
#
#                                               Title               Department  \
# 0                    Managing Partner, Board Member  Office of the President
# 1                                         President  Office of the President
# 2   Executive Vice President of Baseball Operations  Office of the President
# 3                                 Chairman Emeritus  Office of the President
# 4                                      Board Member  Office of the President
# ..                                              ...                      ...
# ...

# %%
final_df[['Year', 'Team', 'NameLast', 'NameFirst', 'Title', 'Department', 'Source of Information']] \
    .to_excel(f'../out/{team}-{min(_source.keys())}-to-{max(_source.keys())}.xlsx', index=False)
