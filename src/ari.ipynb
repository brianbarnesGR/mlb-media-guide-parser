# %%
import pandas as pd
from bs4 import BeautifulSoup
from nameparser import HumanName
import requests

# %%
team = 'ARI'
final_df = pd.DataFrame()

_source = {
    2023: 'https://web.archive.org/web/20230321004103/https://www.mlb.com/dbacks/team/front-office',
    2022: 'https://web.archive.org/web/20220314032747/https://www.mlb.com/dbacks/team/front-office',
    2021: 'https://web.archive.org/web/20210331153441/https://www.mlb.com/dbacks/team/front-office',
    2020: 'https://web.archive.org/web/20200303211510/https://www.mlb.com/dbacks/team/front-office',
    2019: 'https://web.archive.org/web/20190330120451/https://www.mlb.com/dbacks/team/front-office',
    2018: 'https://web.archive.org/web/20180301114256https://www.mlb.com/dbacks/team/front-office',
    2017: 'https://web.archive.org/web/20170314071935/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari',
    2016: 'https://web.archive.org/web/20160324234853/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari',
    2015: 'https://web.archive.org/web/20150310083924/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari',
    2014: 'https://web.archive.org/web/20140304082217/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari',
    2013: 'https://web.archive.org/web/20130301004630/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari',
    2012: 'https://web.archive.org/web/20120509173517/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari',
    2011: 'https://web.archive.org/web/20110610131828/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari'
    # 2009: 'https://web.archive.org/web/20090430041816/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari'
    # 2008: 'https://web.archive.org/web/20080213001036/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari',
    # 2007: 'https://web.archive.org/web/20070410115212/http://arizona.diamondbacks.mlb.com/team/front_office.jsp?c_id=ari'
}

# %% [markdown]
# # 2017 and prior

# %%
for year in _source.keys():
    if year <= 2017:
        res = requests.get(_source[year])
        soup = BeautifulSoup(res.content)

        names = [x.text for x in soup.select('h5, dt:first-child, dd:first-child')]
        titles = [x.text for x in soup.select('h5, dt:nth-child(2), dd:nth-child(2)')]

        temp_df = pd.DataFrame({
            'Name': names,
            'Title': titles
        })

        temp_df['NameLast'] = temp_df.Name.apply(lambda x: HumanName(x).last)
        temp_df['NameFirst'] = temp_df.Name.apply(lambda x: HumanName(x).first)

        dep = ''
        departments = []

        for i in range(len(temp_df.Name)):
            if temp_df.iloc[i].Name == temp_df.iloc[i].Title:
                dep = temp_df.iloc[i].Name
            
            departments.append(dep)

        temp_df['Department'] = departments
        temp_df['Team'] = team
        temp_df['Year'] = year
        temp_df['Source of Information'] = _source[year]

        temp_df = temp_df[temp_df.Name != temp_df.Department][['Year', 'Team', 'NameLast', 'NameFirst', 'Title', 'Department', 'Source of Information']]

        final_df = pd.concat([final_df, temp_df])

# %%
final_df.Year.sort_values().unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023])

# %% [markdown]
# # 2018 - Present

# %%
front_office_directory = dict()
temp_df = pd.DataFrame()

for year in _source.keys():
    if year >= 2021:
        front_office_directory[year] = pd.read_html(_source[year])

# %%
employees = {
    2023: {
        'Executive Office': front_office_directory[2023][1],
        'Administration': front_office_directory[2023][2],
        'Ballpark Operations': front_office_directory[2023][3],
        'Baseball Operations': front_office_directory[2023][4],
        'Broadcasting': front_office_directory[2023][5],
        'Clubhouse Creative': front_office_directory[2023][6],
        'Communications': front_office_directory[2023][7],
        'Community Affairs': front_office_directory[2023][8],
        'Corporate Partnerships': front_office_directory[2023][9],
        'DBTV Productions & Game Operations': front_office_directory[2023][10],
        'Facilities & Event Services': front_office_directory[2023][11],
        'Finance': front_office_directory[2023][12],
        'Information Technology': front_office_directory[2023][13],
        'Legal': front_office_directory[2023][14],
        'Marketing & Business Analytics': front_office_directory[2023][15],
        'People & Culture': front_office_directory[2023][16],
        'Special Projects': front_office_directory[2023][17],
        'Ticketing': front_office_directory[2023][18]
    },
    2022: {
        'Executive Office': front_office_directory[2022][1],
        'Administration/Consultants': front_office_directory[2022][2],
        'Ballpark Operations': front_office_directory[2022][3],
        'Baseball Operations': front_office_directory[2022][4],
        'Broadcasting': front_office_directory[2022][5],
        'Clubhouse Creative': front_office_directory[2022][6],
        'Communications': front_office_directory[2022][7],
        'Community Affairs': front_office_directory[2022][8],
        'Corporate Partnerships': front_office_directory[2022][9],
        'DBTV Productions & Game Operations': front_office_directory[2022][10],
        'Facilities & Event Services': front_office_directory[2022][11],
        'Finance': front_office_directory[2022][12],
        'Information Technology': front_office_directory[2022][13],
        'Legal': front_office_directory[2022][14],
        'Marketing & Business Analytics': front_office_directory[2022][15],
        'People & Culture': front_office_directory[2022][16],
        'Special Projects': front_office_directory[2022][17],
        'Ticketing': front_office_directory[2022][18]
    },
    2021: {
        'Executive Office': front_office_directory[2021][1],
        'Administration/Consultants': front_office_directory[2021][2],
        'Ballpark Operations': front_office_directory[2021][3],
        'Baseball Operations': front_office_directory[2021][4],
        'Broadcasting': front_office_directory[2021][5],
        'Clubhouse Creative': front_office_directory[2021][6],
        'Communications': front_office_directory[2021][7],
        'Community Affairs': front_office_directory[2021][8],
        'Corporate Partnerships': front_office_directory[2021][9],
        'DBTV Productions & Game Operations': front_office_directory[2021][10],
        'Facilities & Event Services': front_office_directory[2021][11],
        'Finance': front_office_directory[2021][12],
        'Information Technology': front_office_directory[2021][13],
        'Legal': front_office_directory[2021][14],
        'Marketing & Business Analytics': front_office_directory[2021][15],
        'People & Culture': front_office_directory[2021][16],
        'Special Projects': front_office_directory[2021][17],
        'Ticketing': front_office_directory[2021][18]
    },
    2020: {
        'Executive Office': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261728944').content)[0],
        'Administration': pd.read_html(requests.get('http://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261734434').content)[0],
        'Baseball Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261734956').content)[0],
        'Broadcasting': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261734956').content)[0],
        'Clubhouse Creative': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735076').content)[0],
        'Communications': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735088').content)[0],
        'Community Affairs': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735378').content)[0],
        'Corporate Partnerships': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735212').content)[0],
        'DBTV Productions & Game Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735504').content)[0],
        'Facilities & Event Services': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735262').content)[0],
        'Finance': pd.read_html(requests.get('https://web.archive.org/web/20190823211205/https://www.mlb.com/tokens/table/261735050').content)[0],
        'Government Affairs': pd.read_html(requests.get('https://web.archive.org/web/20190823211205/https://www.mlb.com/tokens/table/298354402').content)[0],
        'Information Technology': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735664').content)[0],
        'Legal': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735298').content)[0],
        'Marketing': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735712').content)[0],
        'People & Culture': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735648').content)[0],
        'Special Projects': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735724').content)[0],
        'Ticket Sales, Services & Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211205/https://www.mlb.com/tokens/table/261735910').content)[0],
    },
    2019: {
        'Executive Office': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261728944').content)[0],
        'Administration': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261734434').content)[0],
        'Baseball Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735058').content)[0],
        'Broadcasting': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261734956').content)[0],
        'Clubhouse Creative': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735076').content)[0],
        'Communications': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735088').content)[0],
        'Community Affairs': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735378').content)[0],
        'Corporate Partnerships': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735212').content)[0],
        'DBTV Productions & Game Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735504').content)[0],
        'Facilities & Event Services': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735262').content)[0],
        'Finance': pd.read_html(requests.get('https://web.archive.org/web/20190823211205/https://www.mlb.com/tokens/table/261735050').content)[0],
        'Government Affairs': pd.read_html(requests.get('https://web.archive.org/web/20190823211205/https://www.mlb.com/tokens/table/298354402').content)[0],
        'Human Resources': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735648').content)[0],
        'Information Technology': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735664').content)[0],
        'Legal': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735298').content)[0],
        'Marketing': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735712').content)[0],
        'Special Projects': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735724').content)[0],
        'Ticket Sales, Services & Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211205/https://www.mlb.com/tokens/table/261735910').content)[0]
    },
    2018: {
        'Executive Office': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261728944').content)[0],
        'Finance': pd.read_html(requests.get('https://web.archive.org/web/20190823211205/https://www.mlb.com/tokens/table/261735050').content)[0],
        'Administration': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261734434').content)[0],
        'Baseball Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735058').content)[0],
        'Broadcasting': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261734956').content)[0],
        'Clubhouse Creative': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735076').content)[0],
        'Communications': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735088').content)[0],
        'Community Affairs': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735378').content)[0],
        'Corporate Partnerships': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735212').content)[0],
        'DBTV Productions & Game Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735504').content)[0],
        'Facilities & Event Services': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735262').content)[0],
        'Human Resources': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735648').content)[0],
        'Information Technology': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735664').content)[0],
        'Legal': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735298').content)[0],
        'Marketing': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735712').content)[0],
        'Special Projects': pd.read_html(requests.get('https://web.archive.org/web/20190823211204/https://www.mlb.com/tokens/table/261735724').content)[0],
        'Ticket Sales, Services & Operations': pd.read_html(requests.get('https://web.archive.org/web/20190823211205/https://www.mlb.com/tokens/table/261735910').content)[0]
    }
}

# %%
for year in range(max([min(_source.keys()), 2018]), max(_source.keys()) + 1):
    for k in employees[year]:
        employees[year][k]['Year'] = year
        employees[year][k]['Department'] = k
        employees[year][k]['Source of Information'] = _source[year]
        temp_df = pd.concat((temp_df, employees[year][k]))


temp_df.dropna(subset=['Name', 'Title'], inplace=True)
temp_df['Team'] = team
temp_df['NameLast'] = temp_df.Name.apply(lambda x: HumanName(x).last)
temp_df['NameFirst'] = temp_df.Name.apply(lambda x: HumanName(x).first)

temp_df = temp_df[['Year', 'Team', 'NameLast', 'NameFirst', 'Title', 'Department', 'Source of Information']]

# %%
final_df = pd.concat([temp_df, final_df])

# %%
final_df
# Out:
#      Year Team  NameLast NameFirst  \
# 0    2018  ARI  Kendrick       Ken
# 1    2018  ARI   Chipman      Mike
# 2    2018  ARI     Royer      Jeff
# 3    2018  ARI      Hall   Derrick
# 4    2018  ARI     Hazen      Mike
# ..    ...  ...       ...       ...
# 293  2011  ARI  Martines    Andrew
# 294  2011  ARI    Rooney     Brian
# 295  2011  ARI     Smith      Matt
# 296  2011  ARI     Simon      Josh
# 298  2011  ARI   Lincoln      Tina
#
#                                           Title  \
# 0                      Managing General Partner
# 1                               General Partner
# 2                               General Partner
# 3           President & Chief Executive Officer
# 4    Executive Vice President & General Manager
# ..                                          ...
# 293                            Sales Consultant
# 294                            Sales Consultant
# 295                            Sales Consultant
# ...

# %%
final_df[['Year', 'Team', 'NameLast', 'NameFirst', 'Title', 'Department', 'Source of Information']] \
    .to_excel(f'../out/{team}-{min(_source.keys())}-to-{max(_source.keys())}.xlsx', index=False)
